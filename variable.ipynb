# %%
phone_number =345566

print(phone_number)

name = "fahim"
print(name)

age =20
height=5.8
name ="fahim"
is_passed = True

print(type(age),type(height),type (name),type(is_passed))
# Out:
# 345566
# fahim
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
