# %% [markdown]
# ### problem 1 - 3 5 9 10 15 18 20 21 --output 3 9 18 21

# %%
numbers = list(map(int, input().split()))
result = [n for n in numbers if n % 3 == 0 and n % 5 != 0]
print(result)
# Out:
# []

# %%
numbers = list(map(int, input().split()))

result = []

for n in numbers:
    if n % 3 == 0 and n % 5 != 0:
        result.append(n)
    else:
        pass

print(result)
# Out:
# [6, 12]

# %%
numbers = list(map(int, input().split()))

result = list(filter(lambda n: n % 3 == 0 and n % 5 != 0, numbers))

print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 numbers = list(map(int, input().split()))
#       3 result = list(filter(lambda n: n % 3 == 0 and n % 5 != 0, numbers))
#       5 print(result)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# ...

# %%
inp = input()
numbers = inp.split()
numbers = list(map(int,numbers))  #alternative - numbers = [int(x) for x in inp.split()]

result = list(filter(lambda n: n % 3 == 0 and n % 5 != 0, numbers))

print(result)
# Out:
# [3, 9, 18, 21]

# %%
#### fun 

nums = [1, 2, 3, 4, 5, 6]

result = list(
    map(lambda x: x * 2,
        filter(lambda x: x % 2 == 0, nums)) #filter → [2, 4, 6] map → [4, 8, 12]
)
# alternative------- result = [x * 2 for x in nums if x % 2 == 0]
print(result)

# %% [markdown]
# ### problem 2

# %%
try:
  file = open("./sample_data/data1.txt","r")

except Exception as e:
  print(e)
else:
  #model train
  print(file.read())
finally:
  print("GPU is stopeed")
# Out:
# [Errno 2] No such file or directory: './sample_data/data1.txt'
# GPU is stopeed

# %%
def compute(a, b):
    try:
        result = (a**2 + b**2) / (a - b)
        return result
    except ZeroDivisionError:
        return "Error: Division not possible"

a, b = map(int, input().split())
print(compute(a, b))
# Out:
# 61.0

# %%
def compute(a, b):
    try:
        result = (a**2 + b**2) / (a - b)
        return result
    except Exception as e:
        return e

a, b = map(int, input().split())
print(compute(a, b))
# Out:
# 61.0

# %% [markdown]
# ### problem 4

# %%
sent = input()
sentence = sent.split()
word_lengths = []
for word in sentence :
    word_lengths.append(len(word))
print(word_lengths)
# Out:
# [1, 4, 5]

# %%
sentence = input()

word_lengths = [len(word) for word in sentence.split()]

print(word_lengths)
# Out:
# [1, 4, 1]

# %% [markdown]
# ### problem 5

# %%
n = input()

if n == n[::-1]:
    print("Mirror Number")
else:
    print("Not Mirror Number")

# %% [markdown]
# ### problem 3

# %%
import string

# Open and read the file
with open("data.txt", "r") as file:
    text = file.read()

# Convert to lowercase (ignore case sensitivity)
text = text.lower()

# Remove punctuation marks
for char in string.punctuation:
    text = text.replace(char, "")

# Split into words
words = text.split()

# Count frequency of each word
word_count = {}
for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

# Find the most frequently occurring word
most_frequent = max(word_count, key=lambda k: word_count[k])

print(most_frequent)
