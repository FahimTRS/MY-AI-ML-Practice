# %%
A = { 1, 2 , 3 } 

print(type(A) , A )
# Out:
# <class 'set'> {1, 2, 3}

# %%
## empty structures 
B = [] 

print(type(B)) 

C= () 

print(type(C))


S = set()   # S = {}---dictionary bujabe jodi empty raki

print(type(S))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>

# %%
#accessing 

S= { 1 ,2 ,3 , 4 ,1 ,2 } 

if (10 in S):
    print("3 is present")
else:
    print("not present")

sum =0 

for element in S:
    sum+= element 

print(sum)
# Out:
# not present
# 10

# %%
#mutable

s= {5, 1 , 2 ,4, 3} 

s.add(10) 
s.add(0)

print(s)

s.pop()
s.pop()
print(s)

s.remove(5) 

print(s)
# Out:
# {0, 1, 2, 3, 4, 5, 10}
# {2, 3, 4, 5, 10}
# {2, 3, 4, 10}

# %% [markdown]
# ### Method of set

# %%
a = { 1, 2, 3 } 
b = {1, 2 , 5,6, 4 } 

print( a.union(b) )

print(a.intersection(b)) 


print(a.isdisjoint(b)) 


print(a.issubset(b))
