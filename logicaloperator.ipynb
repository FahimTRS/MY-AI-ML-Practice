# %%
x = 10; y = 5; z = 3 

result = ( x > y ) and ( x > z )

print (result)
# Out:
# True

# %%
x = 10; y = 5; z = 3 

result = ( x > y ) or ( x > z )

print (result)
# Out:
# True

# %%
eq = 10 + 10/2 - 5 *2 #precedence and associativity
print (eq)
# Out:
# 5.0
