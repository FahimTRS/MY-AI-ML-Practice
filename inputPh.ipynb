# %%
name = input("your name?")
print(name)
# Out:
# fahim

# %%
age =input("age?")
age =int(age) #string ashbe nah, integer hbe
print (age, type (age)) #string sole ashbe
# Out:
# 26 <class 'int'>

# %%
height= float(input("height?")) #direct floating
height = height + 1.2
print (height, type(height))
# Out:
# 7.0 <class 'float'>
