# %%
x= 10; y= 3

sum = x + y
sub = x - y
mult = x * y
div = round (x / y, 2 ) 
rem = x % y 

print(sum, sub, mult, div, rem)
# Out:
# 13 7 30 3.33 1

# %%
x= 10; y= 3
greather_than = x > y
less_than_0r_equal = 10 <= 10 
equal = x==y
not_equal = x!=y

print (greather_than, less_than_0r_equal, equal, not_equal )
# Out:
# True True False True
